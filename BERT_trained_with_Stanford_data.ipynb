# %% [markdown]
# <a href="https://colab.research.google.com/github/boyuan5022/BERT-trained-with-Stanford-data/blob/main/BERT_trained_with_Stanford_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train Model

# %%
# !pip install transformers
from transformers import BertTokenizer, TFBertForSequenceClassification, InputExample, InputFeatures
import tensorflow as tf
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

def convert_data_to_examples(train, test, DATA_COLUMN, LABEL_COLUMN):
    train_InputExamples = train.apply(
        lambda x: InputExample(guid=None,  # Globally unique ID for bookkeeping, unused in this case
                               text_a=x[DATA_COLUMN],
                               text_b=None,
                               label=x[LABEL_COLUMN]), axis=1)

    validation_InputExamples = test.apply(
        lambda x: InputExample(guid=None,  # Globally unique ID for bookkeeping, unused in this case
                               text_a=x[DATA_COLUMN],
                               text_b=None,
                               label=x[LABEL_COLUMN]), axis=1)

    return train_InputExamples, validation_InputExamples

def convert_examples_to_tf_dataset(examples, tokenizer, max_length=128):
    features = []  # -> will hold InputFeatures to be converted later

    for e in examples:
        # Documentation is really strong for this method, so please take a look at it
        input_dict = tokenizer.encode_plus(
            e.text_a,
            add_special_tokens=True,
            max_length=max_length,  # truncates if len(s) > max_length
            return_token_type_ids=True,
            return_attention_mask=True,
            pad_to_max_length=True,  # pads to the right by default # CHECK THIS for pad_to_max_length
            truncation=True
        )

        input_ids, token_type_ids, attention_mask = (input_dict["input_ids"],
                                                     input_dict["token_type_ids"], input_dict['attention_mask'])

        features.append(
            InputFeatures(
                input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, label=e.label
            )
        )

    def gen():
        for f in features:
            yield (
                {
                    "input_ids": f.input_ids,
                    "attention_mask": f.attention_mask,
                    "token_type_ids": f.token_type_ids,
                },
                f.label,
            )

    return tf.data.Dataset.from_generator(
        gen,
        ({"input_ids": tf.int32, "attention_mask": tf.int32, "token_type_ids": tf.int32}, tf.int64),
        (
            {
                "input_ids": tf.TensorShape([None]),
                "attention_mask": tf.TensorShape([None]),
                "token_type_ids": tf.TensorShape([None]),
            },
            tf.TensorShape([]),
        ),
    )

model = TFBertForSequenceClassification.from_pretrained("bert-base-uncased")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model.summary()

URL = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file(fname="aclImdb_v1.tar.gz",
                                  origin=URL,
                                  untar=True,
                                  cache_dir='.',
                                  cache_subdir='')

# The shutil module offers a number of high-level
# operations on files and collections of files.
import os
import shutil
# Create main directory path ("/aclImdb")
main_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')
# Create sub directory path ("/aclImdb/train")
train_dir = os.path.join(main_dir, 'train')
# Remove unsup folder since this is a supervised learning task
remove_dir = os.path.join(train_dir, 'unsup')
shutil.rmtree(remove_dir)
# View the final train folder
print(os.listdir(train_dir))

# We create a training dataset and a validation
# dataset from our "aclImdb/train" directory with a 80/20 split.
train = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', batch_size=30000, validation_split=0.2,
    subset='training', seed=123)
test = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', batch_size=30000, validation_split=0.2,
    subset='validation', seed=123)

for i in train.take(1):
  train_feat = i[0].numpy()
  train_lab = i[1].numpy()

train = pd.DataFrame([train_feat, train_lab]).T
train.columns = ['DATA_COLUMN', 'LABEL_COLUMN']
train['DATA_COLUMN'] = train['DATA_COLUMN'].str.decode("utf-8")

for j in test.take(1):
  test_feat = j[0].numpy()
  test_lab = j[1].numpy()

test = pd.DataFrame([test_feat, test_lab]).T
test.columns = ['DATA_COLUMN', 'LABEL_COLUMN']
test['DATA_COLUMN'] = test['DATA_COLUMN'].str.decode("utf-8")

DATA_COLUMN = 'DATA_COLUMN'
LABEL_COLUMN = 'LABEL_COLUMN'

train_InputExamples, validation_InputExamples = convert_data_to_examples(train, test, DATA_COLUMN, LABEL_COLUMN)

train_data = convert_examples_to_tf_dataset(list(train_InputExamples), tokenizer)
train_data = train_data.shuffle(100).batch(32).repeat(2)

validation_data = convert_examples_to_tf_dataset(list(validation_InputExamples), tokenizer)
validation_data = validation_data.batch(32)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5, epsilon=1e-08, clipnorm=1.0),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy('accuracy')])
checkpoint_path = "training_1/cp.ckpt"
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
model.fit(train_data, epochs=1, validation_data=validation_data,callbacks=[cp_callback])
model.save_weights('/content/drive/MyDrive/Colab Notebooks/Checkpoint/my_checkpoint')
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.4.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.embeddings.word_embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.embeddings.word_embeddings.weight
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.embeddings.position_embeddings.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.embeddings.token_type_embeddings.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.intermediate.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.intermediate.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.bert_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.bert_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.0.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.1.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.2.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.3.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.4.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.5.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.6.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.7.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.8.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.9.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.10.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.self_attention.query.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.self_attention.query.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.self_attention.key.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.self_attention.key.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.self_attention.value.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.self_attention.value.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.dense_output.dense.partial_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).bert.encoder.layer.11.attention.dense_output.dense.full_output_shape
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).classifier.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).classifier.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.embeddings.word_embeddings.weight
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.embeddings.position_embeddings.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.embeddings.token_type_embeddings.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.embeddings.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.embeddings.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.pooler.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.pooler.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.intermediate.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.intermediate.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.query.bias
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.query.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.query.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.key.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.key.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.value.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.value.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# Model: "tf_bert_for_sequence_classification_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bert (TFBertMainLayer)       multiple                  109482240
# _________________________________________________________________
# dropout_189 (Dropout)        multiple                  0
# _________________________________________________________________
# classifier (Dense)           multiple                  1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Downloading data from https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# 84131840/84125825 [==============================] - 3s 0us/step
# ['urls_unsup.txt', 'neg', 'urls_pos.txt', 'unsupBow.feat', 'pos', 'urls_neg.txt', 'labeledBow.feat']
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2074: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7eff98e83ec0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7eff98e83ec0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7effb4735c20> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function wrap at 0x7effb4735c20> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
#    1250/Unknown - 1070s 815ms/step - loss: 0.3565 - accuracy: 0.8353WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 1250/1250 [==============================] - 1115s 851ms/step - loss: 0.3564 - accuracy: 0.8354 - val_loss: 0.2804 - val_accuracy: 0.8852
#
# Epoch 00001: saving model to training_1/cp.ckpt

# %% [markdown]
# # Apply model to excel

# %%
# !pip install transformers
# !pip install openpyxl
from transformers import BertTokenizer, TFBertForSequenceClassification, InputExample, InputFeatures
import tensorflow as tf
import pandas as pd
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter
import os
import numpy as np
from string import ascii_lowercase
from numpy import concatenate

def excel_sentiment(input_file,output_file,model_file,column_letter):
  #Converts Excel column letters to strings
  LETTERS = {letter: str(index) for index, letter in enumerate(ascii_lowercase, start=1)}

  #Creates list of input strings for model
  data_table = pd.read_excel(input_file)
  predsentences = data_table[data_table.columns[int(LETTERS[column_letter])-1]].to_list()
  pred_sentences = ["" if x is np.nan else " ".join(str(x).replace("\'","").replace("\"", "").splitlines()) for x in predsentences]

  #Create model and load the previously saved weights
  checkpoint_dir = os.path.dirname(model_file)
  latest = tf.train.latest_checkpoint(checkpoint_dir)
  model = TFBertForSequenceClassification.from_pretrained("bert-base-uncased")
  model.load_weights(latest).expect_partial() 
  tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
  labels = ['Negative','Positive']

  label=[]
  confidence=[]
  for i in range(0,len(pred_sentences),200):
    upper_bound=min(i+200,len(pred_sentences))
    temp_label=[]
    pred_sentences_chunk=[]
    pred_sentences_chunk=pred_sentences[i:upper_bound]
    tf_batch = tokenizer(pred_sentences_chunk, padding=True, truncation=True, return_tensors='tf')
    tf_outputs = model(tf_batch)
    tf_predictions = tf.nn.softmax(tf_outputs[0], axis=-1)
    temp_label = tf.argmax(tf_predictions, axis=1)
    temp_label = temp_label.numpy()
    temp_confidence=[max(x) for x in tf_predictions.numpy()]
    label=concatenate([label,temp_label])
    confidence=concatenate([confidence,temp_confidence])

  #Writes output into excel file in last column. GPU restrictions mean only 200 strings can be plugged into the model at a time.
  wb = load_workbook(filename = input_file)
  ws = wb.active
  maxcolumn=ws.max_column
  ws[get_column_letter(maxcolumn+1)+"1"]="Sentiment"
  ws[get_column_letter(maxcolumn+2)+"1"]="Confidence"
  for i in range(len(label)):
    ws[get_column_letter(maxcolumn+1)+str(i+2)]="" if pred_sentences[i]=="" else labels[label[i].astype(int)]
    ws[get_column_letter(maxcolumn+2)+str(i+2)]="" if pred_sentences[i]=="" else confidence[i]
  wb.save(filename = output_file)
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.4.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.4.1)

# %% [markdown]
# # Test

# %%
# !pip install transformers
# !pip install openpyxl
from transformers import BertTokenizer, TFBertForSequenceClassification, InputExample, InputFeatures
import tensorflow as tf
import pandas as pd
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter
import os
import numpy as np
from string import ascii_lowercase
from numpy import concatenate

def test_excel_sentiment(model_file,sentences):

  #Create model and load the previously saved weights
  checkpoint_dir = os.path.dirname(model_file)
  latest = tf.train.latest_checkpoint(checkpoint_dir)
  model = TFBertForSequenceClassification.from_pretrained("bert-base-uncased")
  model.load_weights(latest).expect_partial() 
  tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
  labels = ['Negative','Positive']
  label=[]
  temp_label=[]
  confidence=[]
  output=[]
  tf_batch = tokenizer(sentences, padding=True, truncation=True, return_tensors='tf')
  tf_outputs = model(tf_batch)
  tf_predictions = tf.nn.softmax(tf_outputs[0], axis=-1)
  temp_label = tf.argmax(tf_predictions, axis=1)
  temp_label = temp_label.numpy()
  temp_confidence=[max(x) for x in tf_predictions.numpy()]
  label=concatenate([label,temp_label])
  confidence=concatenate([confidence,temp_confidence])
  for i in range(0,len(label)):
    output=concatenate([output,[labels[temp_label[i].astype(int)]+" with "+str(round(confidence[i]*100))+"% confidence"]])
  return output

test1="The steering wheel is unpredictable."
test2="The audio quality of my new laptop is so cool but the display colors are not too good."
test3="This is an awesome product ! I've tried several BT options for the switch and this one seems to have the best quality with no lag and extremely easy to use ! Even has the mini mic so you can use in game chat however only in handheld unless the switch is docked right next to you. I had some questions about the mic and dealing with customer service was great ! They were extremely friendly, quick to respond and great at answering my questions."
print(test_excel_sentiment("/content/drive/MyDrive/Colab Notebooks/Checkpoints/cp.ckpt",[test1,test2,test3]))
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.0.1)
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ['Negative with 85% confidence' 'Negative with 52% confidence'
#  'Positive with 99% confidence']

# %% [markdown]
# # Full Demo

# %%
from google.colab import drive 
drive.mount('/content/drive')

excel_sentiment("/content/drive/MyDrive/Colab Notebooks/Reviews.xlsx","/content/drive/MyDrive/Colab Notebooks/output.xlsx","/content/drive/MyDrive/Colab Notebooks/Checkpoints/cp.ckpt","g")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
